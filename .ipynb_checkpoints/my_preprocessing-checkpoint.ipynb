# %%
import pandas as pd
import numpy as np
my_total_data = pd.read_csv('Project_datamining_final_data_03_12_an1 - Project_datamining_final_data_03_12_an1.csv')

# %%
my_total_data.head()
# Out:
#    CleEffet       Date     TypeEffet        FamilleArticle Code Produit  \
# 0         1  8/14/2012  Bon d'entrée  Produit Insecticides     0305-004
# 1         1  8/14/2012  Bon d'entrée        Matériel bovin        11250
# 2         1  8/14/2012  Bon d'entrée  Produit Insecticides     0305-039
# 3         1  8/14/2012  Bon d'entrée  Produit Insecticides   2F18272093
# 4         1  8/14/2012  Bon d'entrée  Produit Insecticides     0305-054
#
#   Reference Produit         NLot Produit_Designation DetailEffet_Designation  \
# 0               305    CHA110501      Produit_Anon_0           Detail_Anon_0
# 1               305  10.274.1.09      Produit_Anon_1           Detail_Anon_1
# 2               305      L110703      Produit_Anon_2           Detail_Anon_2
# 3        2F18272093   2F18272093      Produit_Anon_3           Detail_Anon_3
# 4               305     20101102      Produit_Anon_4           Detail_Anon_4
#
#    Quantite PrixAchat PrixUnitaireTTC DetailEffet_Marge     Effet_Marge  \
# 0      65.0  1,650.00        9,999.00                 0  216,310,866.75
# 1     120.0       550        9,999.00                 0  216,310,866.75
# 2     137.0  1,034.00        9,999.00                 0  216,310,866.75
# 3    2000.0  2,800.00        9,999.00                 0  216,310,866.75
# 4    3500.0  1,550.00        9,999.00                 0  216,310,866.75
#
#         MontantHT Payement
# 0  216,310,866.75        0
# 1  216,310,866.75        0
# 2  216,310,866.75        0
# 3  216,310,866.75        0
# 4  216,310,866.75        0

# %%
num_rows, num_columns = my_total_data.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 261001
# Number of columns: 16

# %%
my_total_data.dtypes
# Out:
# CleEffet                     int64
# Date                        object
# TypeEffet                   object
# FamilleArticle              object
# Code Produit                object
# Reference Produit           object
# NLot                        object
# Produit_Designation         object
# DetailEffet_Designation     object
# Quantite                   float64
# PrixAchat                   object
# PrixUnitaireTTC             object
# DetailEffet_Marge           object
# Effet_Marge                 object
# MontantHT                   object
# Payement                    object
# dtype: object

# %% [markdown]
# **Converting the data types**

# %%
#converting the date 

my_total_data['Date'] = pd.to_datetime(my_total_data['Date'])
print(my_total_data.dtypes)
# Out:
# CleEffet                            int64
# Date                       datetime64[ns]
# TypeEffet                          object
# FamilleArticle                     object
# Code Produit                       object
# Reference Produit                  object
# NLot                               object
# Produit_Designation                object
# DetailEffet_Designation            object
# Quantite                          float64
# PrixAchat                          object
# PrixUnitaireTTC                    object
# DetailEffet_Marge                  object
# Effet_Marge                        object
# MontantHT                          object
# Payement                           object
# dtype: object

# %%
print(my_total_data.head())
# Out:
#    CleEffet       Date     TypeEffet        FamilleArticle Code Produit  \
# 0         1 2012-08-14  Bon d'entrée  Produit Insecticides     0305-004
# 1         1 2012-08-14  Bon d'entrée        Matériel bovin        11250
# 2         1 2012-08-14  Bon d'entrée  Produit Insecticides     0305-039
# 3         1 2012-08-14  Bon d'entrée  Produit Insecticides   2F18272093
# 4         1 2012-08-14  Bon d'entrée  Produit Insecticides     0305-054
#
#   Reference Produit         NLot Produit_Designation DetailEffet_Designation  \
# 0               305    CHA110501      Produit_Anon_0           Detail_Anon_0
# 1               305  10.274.1.09      Produit_Anon_1           Detail_Anon_1
# 2               305      L110703      Produit_Anon_2           Detail_Anon_2
# 3        2F18272093   2F18272093      Produit_Anon_3           Detail_Anon_3
# 4               305     20101102      Produit_Anon_4           Detail_Anon_4
#
#    Quantite PrixAchat PrixUnitaireTTC DetailEffet_Marge     Effet_Marge  \
# 0      65.0  1,650.00        9,999.00                 0  216,310,866.75
# 1     120.0       550        9,999.00                 0  216,310,866.75
# 2     137.0  1,034.00        9,999.00                 0  216,310,866.75
# 3    2000.0  2,800.00        9,999.00                 0  216,310,866.75
# 4    3500.0  1,550.00        9,999.00                 0  216,310,866.75
#
#         MontantHT Payement
# 0  216,310,866.75        0
# 1  216,310,866.75        0
# 2  216,310,866.75        0
# 3  216,310,866.75        0
# 4  216,310,866.75        0

# %%
my_total_data.head()
# Out:
#    CleEffet       Date     TypeEffet        FamilleArticle Code Produit  \
# 0         1 2012-08-14  Bon d'entrée  Produit Insecticides     0305-004
# 1         1 2012-08-14  Bon d'entrée        Matériel bovin        11250
# 2         1 2012-08-14  Bon d'entrée  Produit Insecticides     0305-039
# 3         1 2012-08-14  Bon d'entrée  Produit Insecticides   2F18272093
# 4         1 2012-08-14  Bon d'entrée  Produit Insecticides     0305-054
#
#   Reference Produit         NLot Produit_Designation DetailEffet_Designation  \
# 0               305    CHA110501      Produit_Anon_0           Detail_Anon_0
# 1               305  10.274.1.09      Produit_Anon_1           Detail_Anon_1
# 2               305      L110703      Produit_Anon_2           Detail_Anon_2
# 3        2F18272093   2F18272093      Produit_Anon_3           Detail_Anon_3
# 4               305     20101102      Produit_Anon_4           Detail_Anon_4
#
#    Quantite PrixAchat PrixUnitaireTTC DetailEffet_Marge     Effet_Marge  \
# 0      65.0  1,650.00        9,999.00                 0  216,310,866.75
# 1     120.0       550        9,999.00                 0  216,310,866.75
# 2     137.0  1,034.00        9,999.00                 0  216,310,866.75
# 3    2000.0  2,800.00        9,999.00                 0  216,310,866.75
# 4    3500.0  1,550.00        9,999.00                 0  216,310,866.75
#
#         MontantHT Payement
# 0  216,310,866.75        0
# 1  216,310,866.75        0
# 2  216,310,866.75        0
# 3  216,310,866.75        0
# 4  216,310,866.75        0

# %%
num_famille_article = my_total_data['FamilleArticle'].nunique()
print(f"Number of unique values in FamilleArticle: {num_famille_article}")
# Out:
# Number of unique values in FamilleArticle: 92

# %%
#occurences of each family 
famille_article_counts = my_total_data['FamilleArticle'].value_counts()

# Display the counts
print("Occurrences of each FamilleArticle:")
print(famille_article_counts)
# Out:
# Occurrences of each FamilleArticle:
# FamilleArticle
# Detail                  40243
# Produit Engrais         24648
# Produit Insecticides    20771
# Matériel apiculture     19080
# Produit Fongicides      17612
#                         ...
# Semences Artichaut         15
# semmence poureau           12
# Plants pommier              3
# Semences Braka              2
# PLANTS PRUNIER              2
# Name: count, Length: 92, dtype: int64

# %%
my_total_data.dtypes
# Out:
# CleEffet                            int64
# Date                       datetime64[ns]
# TypeEffet                          object
# FamilleArticle                     object
# Code Produit                       object
# Reference Produit                  object
# NLot                               object
# Produit_Designation                object
# DetailEffet_Designation            object
# Quantite                          float64
# PrixAchat                          object
# PrixUnitaireTTC                    object
# DetailEffet_Marge                  object
# Effet_Marge                        object
# MontantHT                          object
# Payement                           object
# dtype: object

# %%
# Define the columns to be converted
columns_to_convert = ['PrixAchat', 'PrixUnitaireTTC', 'DetailEffet_Marge', 'Effet_Marge', 'MontantHT', 'Payement']

# Step 1: Remove commas from large numbers
for col in columns_to_convert:
    my_total_data[col] = my_total_data[col].str.replace(',', '')

# Step 2: Convert to float64
my_total_data[columns_to_convert] = my_total_data[columns_to_convert].apply(pd.to_numeric, errors='coerce')

# Display the updated data types
print(my_total_data[columns_to_convert].dtypes)

# Display the first few rows of the DataFrame to check if the conversion is successful
print(my_total_data.head())
# Out:
# PrixAchat            float64
# PrixUnitaireTTC      float64
# DetailEffet_Marge    float64
# Effet_Marge          float64
# MontantHT            float64
# Payement             float64
# dtype: object
#    CleEffet       Date     TypeEffet        FamilleArticle Code Produit  \
# 0         1 2012-08-14  Bon d'entrée  Produit Insecticides     0305-004
# 1         1 2012-08-14  Bon d'entrée        Matériel bovin        11250
# 2         1 2012-08-14  Bon d'entrée  Produit Insecticides     0305-039
# 3         1 2012-08-14  Bon d'entrée  Produit Insecticides   2F18272093
# 4         1 2012-08-14  Bon d'entrée  Produit Insecticides     0305-054
#
#   Reference Produit         NLot Produit_Designation DetailEffet_Designation  \
# 0               305    CHA110501      Produit_Anon_0           Detail_Anon_0
# 1               305  10.274.1.09      Produit_Anon_1           Detail_Anon_1
# 2               305      L110703      Produit_Anon_2           Detail_Anon_2
# 3        2F18272093   2F18272093      Produit_Anon_3           Detail_Anon_3
# 4               305     20101102      Produit_Anon_4           Detail_Anon_4
#
#    Quantite  PrixAchat  PrixUnitaireTTC  DetailEffet_Marge   Effet_Marge  \
# 0      65.0     1650.0           9999.0                0.0  2.163109e+08
# 1     120.0      550.0           9999.0                0.0  2.163109e+08
# 2     137.0     1034.0           9999.0                0.0  2.163109e+08
# 3    2000.0     2800.0           9999.0                0.0  2.163109e+08
# 4    3500.0     1550.0           9999.0                0.0  2.163109e+08
#
#       MontantHT  Payement
# 0  2.163109e+08       0.0
# 1  2.163109e+08       0.0
# 2  2.163109e+08       0.0
# 3  2.163109e+08       0.0
# 4  2.163109e+08       0.0

# %%
num_rows, num_columns = my_total_data.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_columns}")
# Out:
# Number of rows: 261001
# Number of columns: 16

# %%
my_total_data.dtypes
# Out:
# CleEffet                            int64
# Date                       datetime64[ns]
# TypeEffet                          object
# FamilleArticle                     object
# Code Produit                       object
# Reference Produit                  object
# NLot                               object
# Produit_Designation                object
# DetailEffet_Designation            object
# Quantite                          float64
# PrixAchat                         float64
# PrixUnitaireTTC                   float64
# DetailEffet_Marge                 float64
# Effet_Marge                       float64
# MontantHT                         float64
# Payement                          float64
# dtype: object

# %%
# Convert 'TypeEffet' to a categorical data type
my_total_data['TypeEffet'] = my_total_data['TypeEffet'].astype('category')

# %%
# Print the number of unique categories and their names
num_categories = my_total_data['TypeEffet'].nunique()
categories_names = my_total_data['TypeEffet'].cat.categories

print(f"Number of unique categories in 'TypeEffet': {num_categories}")
print("Category names:")
for category_name in categories_names:
    print(category_name)
# Out:
# Number of unique categories in 'TypeEffet': 4
# Category names:
# Bon d'entrée
# Bon de livraison
# Bon de réception
# Bon de sortie

# %%
my_total_data.dtypes
# Out:
# CleEffet                            int64
# Date                       datetime64[ns]
# TypeEffet                        category
# FamilleArticle                     object
# Code Produit                       object
# Reference Produit                  object
# NLot                               object
# Produit_Designation                object
# DetailEffet_Designation            object
# Quantite                          float64
# PrixAchat                         float64
# PrixUnitaireTTC                   float64
# DetailEffet_Marge                 float64
# Effet_Marge                       float64
# MontantHT                         float64
# Payement                          float64
# dtype: object

# %% [markdown]
# **dealing with missing values**

# %%
missing_percentage = (my_total_data.isnull().mean() * 100).round(2)

# Display the results
print("Percentage of missing data for each column:")
print(missing_percentage)
# Out:
# Percentage of missing data for each column:
# CleEffet                    0.00
# Date                        0.00
# TypeEffet                   0.00
# FamilleArticle              0.00
# Code Produit               38.61
# Reference Produit          48.00
# NLot                       12.40
# Produit_Designation         0.00
# DetailEffet_Designation     0.00
# Quantite                    0.00
# PrixAchat                   0.00
# PrixUnitaireTTC             0.00
# DetailEffet_Marge           0.00
# Effet_Marge                 0.00
# MontantHT                   0.00
# Payement                    0.00
# dtype: float64

# %%
#checking if ref produit and famille effet correlate
grouped_data = my_total_data.groupby('FamilleArticle')['Reference Produit'].nunique()

# Display the groups with more than one unique 'Reference Produit'
print("FamilleArticle with different Reference Produit:")
print(grouped_data[grouped_data > 1])
# Out:
# FamilleArticle with different Reference Produit:
# FamilleArticle
# Chou-fleur_Hybride                             3
# Courgette_Hybride                              3
# Detail                                         2
# Materiels de l'arboriculture                   9
# Matériel Avicole                               6
# Matériel Divers                               50
# Matériel Goûte à goûte                        12
# Matériel apiculture                           19
# Matériel bovin                                24
# Matériel de pompe 400 l                       17
# Matériel des moteur                            4
# Matériel jardinage                            16
# Matériel outils de préparation de la terre    12
# Matériel pulvérisation                        10
# Matériels Tronceneuses                        19
# Matériels d'irrigation                        17
# Matériels du labour                           23
# Matériels joints Spi ou Ressort                2
# Melon_Hybride                                  3
# Pastèque_Hybride                               2
# Poivron_Hybride                                2
# Produit Acaricides                             2
# Produit Engrais                               10
# Produit Fongicides                            19
# Produit Herbicides                             8
# Produit Insecticides                          26
# Prouduits Raticide + anti insect               3
# SEMENCES SEC                                   3
# Sachet potageur                                5
# Semences Mais                                  2
# Semences Navet                                 2
# Semences Persil                                2
# Semences Petit Pois                           11
# Semences Poivron                               2
# Semences Tomate                                2
# Semences carottes                              3
# Semences celeri                                2
# Semences coriandre                             2
# Semences feve                                  4
# Semences gazon                                 3
# Semences haricot                               2
# Semences laitue                                2
# Tomates_Hybride                                5
# matériels de taille                            9
# plantes olives                                 2
# produit biostimulant                           2
# Name: Reference Produit, dtype: int64

# %%
#showing the different references of families who have more than 10 different reference 

# Group by 'FamilleArticle' and check unique values in 'Reference Produit'
grouped_data = my_total_data.groupby('FamilleArticle')['Reference Produit'].nunique()

# Display the 'Reference Produit' values for 'FamilleArticle' with more than 10 unique references
selected_families = grouped_data[grouped_data > 10].index

for famille_article in selected_families:
    references = my_total_data.loc[my_total_data['FamilleArticle'] == famille_article, 'Reference Produit'].unique()
    print(f"FamilleArticle: {famille_article}")
    print(f"Unique References ({len(references)}): {references}")
    print("\n")
# Out:
# FamilleArticle: Matériel Divers
# Unique References (51): ['20000' '8000' '11000' '30000' '999999' '9000' '12000' '14000' '6000'
#  '20831' nan '2000' '20809' '20812' '20810' '20822' '20825' '20826'
#  '20830' '30642' '20834' '20835' '20836' '20837' '20838' '20840' '20841'
#  '20844' '20846' '20847' '20848' '20852' '20855' '20856' '20860' '20861'
#  '20862' '20864' '13324' '13321' '13322' '13323' '20866' '20865' '20522'
#  '21029' '8981' '9762' '9298' '25000' '9302']
#
#
# FamilleArticle: Matériel Goûte à goûte
# Unique References (13): ['10000' '8000' '11000' '12000' '20000' '5000' nan '9000' '20811' '8726'
#  '8727' '30000' '13358']
#
#
# FamilleArticle: Matériel apiculture
# Unique References (20): ['6000' '11000' '8000' '10000' 'KP09FVT' nan '6838' '6280' '6822' '6823'
#  '6834' '6835' '6836' '6837' '6839' '9000' '13354' '9184' '9185' '9186']
#
#
# FamilleArticle: Matériel bovin
# Unique References (25): ['305' '11000' '11300' '11191' nan '11253' '11297' '11301' '11302' '11303'
#  '11304' '11305' '11306' '11307' '11308' '11309' '11310' '11311' '11312'
#  '1000' '20000' '8000' '11244' '9299' '9301']
#
#
# FamilleArticle: Matériel de pompe 400 l
# Unique References (18): ['305' '30000' '8000' nan '11000' '20000' '12000' '6000' '10000' '80000'
#  '8729' '8730' '20853' '20854' '8735' '2000' '9000' '8947']
#
#
# FamilleArticle: Matériel jardinage
# Unique References (17): ['11000' '20000' '8000' '30000' nan '20718' '20857' '20985' '8989' '8990'
#  '8991' '8992' '8993' '8994' '8995' '8996' '8997']
#
#
# FamilleArticle: Matériel outils de préparation de la terre
# Unique References (13): ['20000' '5000' '11000' '8000' nan '8728' 'p49999' '9978' '8887' '8888'
#  '9964' '8889' '8100']
#
#
# FamilleArticle: Matériels Tronceneuses
# Unique References (20): ['30000' '20000' '8000' nan '20832' '20833' '30636' '30637' '30638'
#  '30639' '30640' '30641' '20842' '20843' '20858' '20859' '2000' '8944'
#  '8945' '8946']
#
#
# FamilleArticle: Matériels d'irrigation
# Unique References (18): ['8000' '20000' nan '10000' '200000' '8725' '20823' '20824' '20829'
#  '20999' '11000' '20942' '7000' '8971' '8970' '8972' '13357' '21000']
#
#
# FamilleArticle: Matériels du labour
# Unique References (24): ['13000' '10000' '8000' '13308' nan '20000' '13309' '13310' '13311'
#  '13312' '13313' '13314' '13315' '13316' '13317' '13318' '13319' '20849'
#  '20850' '20851' '13320' '20867' '13325' '2000']
#
#
# FamilleArticle: Produit Fongicides
# Unique References (20): ['304' '12000' '20140630' '305' nan 'GRA3H031B' '20140315' '22222'
#  '(AK00074)' 'AK00074' '146461' 'E006002376' '2014001021' 'EQ23000282'
#  'EQ06002578' '(GRA4D201D)' '2014001023' '2014071601' '20140323' '21218']
#
#
# FamilleArticle: Produit Insecticides
# Unique References (27): ['305' '2F18272093' '20131101' '2014002021' 'F055E6E907' '10388428'
#  '12000' nan '20140508' 'EMGE000359' '1353002' '2014003005' '-20140515'
#  '20140324' 'he-65' 'he-69' 'he-67' 'he-72' 'he-71' 'he-66' 'he-70'
#  'he-68' 'XA4 01' 'XA4 02' 'XA6 01' 'XA6 02' 'XA7 01']
#
#
# FamilleArticle: Semences Petit Pois
# Unique References (12): ['107' '12000' '14000' '1852MC' nan '(1852MC)' '8410579003753' '442604-A'
#  'ON2738' 'ke77' 'mer1527' 'ke7']

# %%
#FamilleArticle who have same Reference Produit

# Group by 'Reference Produit' and check unique values in 'FamilleArticle'
grouped_data = my_total_data.groupby('Reference Produit')['FamilleArticle'].nunique()

# Display 'FamilleArticle' with the same 'Reference Produit'
same_reference_families = grouped_data[grouped_data > 1].index

for reference_code in same_reference_families:
    famille_articles = my_total_data.loc[my_total_data['Reference Produit'] == reference_code, 'FamilleArticle'].unique()
    print(f"Reference Produit: {reference_code}")
    print(f"Different FamilleArticle ({len(famille_articles)}): {famille_articles}")
    print("\n")
# Out:
# Reference Produit: 1000
# Different FamilleArticle (2): ['SEMENCES SEC' 'Matériel bovin']
#
#
# Reference Produit: 10000
# Different FamilleArticle (6): ['Matériel Goûte à goûte' 'Matériels du labour' 'Matériel pulvérisation'
#  'Matériel de pompe 400 l' 'Matériel apiculture' "Matériels d'irrigation"]
#
#
# Reference Produit: 104
# Different FamilleArticle (2): ['Semences Courgette' 'Courgette_Hybride']
#
#
# Reference Produit: 106
# Different FamilleArticle (2): ['Semences Mais' 'Semences gazon']
#
#
# Reference Produit: 11000
# Different FamilleArticle (11): ['Matériel bovin' 'Matériel Divers' 'Matériel pulvérisation'
#  'Matériel jardinage' 'Matériel apiculture' 'Matériel Goûte à goûte'
#  'Matériel outils de préparation de la terre' 'Matériel de pompe 400 l'
#  'matériels de taille' 'Produit Engrais' "Matériels d'irrigation"]
#
#
# Reference Produit: 112
# Different FamilleArticle (2): ['Semences laitue' 'Chou-fleur_Hybride']
#
#
# Reference Produit: 119
# Different FamilleArticle (2): ['Semences Persil' 'Semences carottes']
#
#
# Reference Produit: 120
# Different FamilleArticle (2): ['Semences celeri' 'Semences laitue']
#
#
# Reference Produit: 12000
# Different FamilleArticle (11): ['Semences feve' 'Semences Petit Pois' 'Divers de Hsen'
#  'Matériel Goûte à goûte' 'Produit Engrais' 'Matériel Divers'
#  'Semences gazon' 'Matériel de pompe 400 l' 'tourbe'
#  'Produit Insecticides' 'Produit Fongicides']
#
#
# Reference Produit: 125
# Different FamilleArticle (2): ['Semences Bettrave Rouge' 'produit biostimulant']
#
#
# Reference Produit: 13000
# Different FamilleArticle (3): ['Matériels du labour' 'Matériel pulvérisation'
#  "Materiels de l'arboriculture"]
#
#
# Reference Produit: 132
# Different FamilleArticle (2): ['SEMENCES SEC' 'Semences Mais']
#
#
# Reference Produit: 14000
# Different FamilleArticle (8): ['Grands sachets de Ghazioui' 'Matériel Avicole'
#  "Materiels de l'arboriculture" 'Semences Petit Pois' 'Matériel Divers'
#  'Produit Engrais' 'SEMENCES SEC' 'Semences haricot']
#
#
# Reference Produit: 15000
# Different FamilleArticle (3): ['Produit Engrais' 'Matériel pulvérisation' 'produit biostimulant']
#
#
# Reference Produit: 17000
# Different FamilleArticle (2): ['Plante Fruité Divers' 'Sachet potageur']
#
#
# Reference Produit: 2000
# Different FamilleArticle (4): ['Matériel Divers' 'Matériels Tronceneuses' 'Matériel de pompe 400 l'
#  'Matériels du labour']
#
#
# Reference Produit: 20000
# Different FamilleArticle (15): ['Matériel Divers' 'Matériel outils de préparation de la terre'
#  "Materiels de l'arboriculture" 'Matériel jardinage'
#  'Matériels Tronceneuses' 'Matériel pulvérisation' 'Matériel Avicole'
#  'Matériel de pompe 400 l' 'Matériel Goûte à goûte'
#  "Matériels d'irrigation" 'Matériel des moteur' 'plantes olives'
#  'matériels de taille' 'Matériels du labour' 'Matériel bovin']
#
#
# Reference Produit: 206
# Different FamilleArticle (2): ['Piment_Hybride' 'Poivron_Hybride']
#
#
# Reference Produit: 30000
# Different FamilleArticle (7): ['Matériels Tronceneuses' 'Matériel des moteur'
#  'Matériels joints Spi ou Ressort' 'Matériel Divers'
#  'Matériel de pompe 400 l' 'Matériel jardinage' 'Matériel Goûte à goûte']
#
#
# Reference Produit: 304
# Different FamilleArticle (4): ['Produit Fongicides' 'Produit Herbicides' 'Produit Engrais'
#  'Prouduits Raticide + anti insect']
#
#
# Reference Produit: 305
# Different FamilleArticle (8): ['Produit Insecticides' 'Matériel bovin' 'Produit Acaricides'
#  'Prouduits Raticide + anti insect' 'Produit Engrais'
#  'Matériel de pompe 400 l' 'Produit Fongicides' 'Produit Herbicides']
#
#
# Reference Produit: 401
# Different FamilleArticle (2): ['Poivron_Hybride' 'Semences Poivron']
#
#
# Reference Produit: 5000
# Different FamilleArticle (3): ['Matériel outils de préparation de la terre'
#  "Materiels de l'arboriculture" 'Matériel Goûte à goûte']
#
#
# Reference Produit: 6000
# Different FamilleArticle (5): ['Matériel apiculture' "Materiels de l'arboriculture"
#  'Matériel de pompe 400 l' 'Matériel pulvérisation' 'Matériel Divers']
#
#
# Reference Produit: 7000
# Different FamilleArticle (3): ['Matériels joints membrane' 'ALIMENT DE BETAIL' "Matériels d'irrigation"]
#
#
# Reference Produit: 8000
# Different FamilleArticle (15): ["Matériels d'irrigation" 'Matériel Divers' 'Matériels du labour'
#  'Matériel de pompe 400 l' 'Matériel jardinage' 'Matériel pulvérisation'
#  'Matériel Avicole' 'Matériel des moteur' 'Matériels Tronceneuses'
#  'Matériel Goûte à goûte' "Materiels de l'arboriculture"
#  'Matériel apiculture' 'Matériel outils de préparation de la terre'
#  'Matériels joints Spi ou Ressort' 'Matériel bovin']
#
#
# Reference Produit: 80000
# Different FamilleArticle (2): ['Matériel de pompe 400 l' 'matériels de taille']
#
#
# Reference Produit: 9000
# Different FamilleArticle (6): ["Materiels de l'arboriculture" 'matériels de taille' 'Matériel Divers'
#  'Matériel Goûte à goûte' 'Matériel apiculture' 'Matériel de pompe 400 l']

# %%
# if in the same year, each family article have same reference produit ( beside materiel divers)

# Filter out 'Matériel Divers' for this analysis
filtered_data = my_total_data[my_total_data['FamilleArticle'] != 'Matériel Divers']

# Filter data for the specific year (e.g., 2017)
selected_year_data = filtered_data[filtered_data['Date'].dt.year == 2022]

# Group by 'FamilleArticle' and 'Reference Produit', and count occurrences
grouped_data = selected_year_data.groupby(['FamilleArticle', 'Reference Produit']).size().reset_index(name='count')

# Display 'FamilleArticle' with different 'Reference Produit'
different_references = grouped_data[grouped_data['count'] > 1]['FamilleArticle'].unique()

for famille_article in different_references:
    references = grouped_data[grouped_data['FamilleArticle'] == famille_article]['Reference Produit'].unique()
    print(f"FamilleArticle: {famille_article}")
    print(f"Unique References ({len(references)}): {references}")
    print("\n")
# Out:
# FamilleArticle: Chou-fleur_Hybride
# Unique References (2): ['0111-009' '205']
#
#
# FamilleArticle: Courgette_Hybride
# Unique References (1): ['204']
#
#
# FamilleArticle: Detail
# Unique References (2): ['0203-043' 'DET']
#
#
# FamilleArticle: Materiels de l'arboriculture
# Unique References (5): ['20000' '5000' '6000' '8000' '9000']
#
#
# FamilleArticle: Matériel Avicole
# Unique References (2): ['20000' '4000']
#
#
# FamilleArticle: Matériel Goûte à goûte
# Unique References (5): ['10000' '11000' '13358' '20000' '8000']
#
#
# FamilleArticle: Matériel apiculture
# Unique References (4): ['11000' '6000' '6835' '6839']
#
#
# FamilleArticle: Matériel bovin
# Unique References (12): ['11000' '11244' '11253' '11297' '11302' '11304' '11305' '11306' '11309'
#  '11310' '9299' '9301']
#
#
# FamilleArticle: Matériel de pompe 400 l
# Unique References (7): ['10000' '2000' '20000' '30000' '8000' '8729' '8947']
#
#
# FamilleArticle: Matériel des moteur
# Unique References (2): ['20000' '30000']
#
#
# FamilleArticle: Matériel jardinage
# Unique References (15): ['11000' '20000' '20718' '20857' '20985' '8000' '8989' '8990' '8991'
#  '8992' '8993' '8994' '8995' '8996' '8997']
#
#
# FamilleArticle: Matériel outils de préparation de la terre
# Unique References (6): ['11000' '20000' '5000' '8100' '8728' '9978']
#
#
# FamilleArticle: Matériel pulvérisation
# Unique References (6): ['10301' '13000' '15000' '20000' '6000' '8000']
#
#
# FamilleArticle: Matériels Tronceneuses
# Unique References (3): ['30000' '8000' '8946']
#
#
# FamilleArticle: Matériels d'irrigation
# Unique References (5): ['20000' '20823' '20824' '8000' '8971']
#
#
# FamilleArticle: Matériels du labour
# Unique References (5): ['13000' '13315' '13317' '20000' '8000']
#
#
# FamilleArticle: Melon_Hybride
# Unique References (1): ['201']
#
#
# FamilleArticle: Pastèque_Hybride
# Unique References (1): ['203']
#
#
# FamilleArticle: Piment_Hybride
# Unique References (1): ['206']
#
#
# FamilleArticle: Plante Fruité Divers
# Unique References (1): ['17000']
#
#
# FamilleArticle: Poivron_Hybride
# Unique References (1): ['401']
#
#
# FamilleArticle: Produit Acaricides
# Unique References (1): ['305']
#
#
# FamilleArticle: Produit Engrais
# Unique References (2): ['15000' '305']
#
#
# FamilleArticle: Produit Fongicides
# Unique References (6): ['(GRA4D201D)' '146461' '304' '305' 'E006002376' 'EQ23000282']
#
#
# FamilleArticle: Produit Herbicides
# Unique References (4): ['20140415' '303' '81595516kO' 'EFKM90014079101813']
#
#
# FamilleArticle: Produit Insecticides
# Unique References (7): ['20131101' '2014002021' '2014003005' '20140508' '305' 'XA4 01' 'he-70']
#
#
# FamilleArticle: Prouduits Raticide + anti insect
# Unique References (2): ['305' '306']
#
#
# FamilleArticle: SEMENCES SEC
# Unique References (1): ['132']
#
#
# FamilleArticle: Semences Avoine
# Unique References (1): ['124']
#
#
# FamilleArticle: Semences Bettrave Rouge
# Unique References (1): ['125']
#
#
# FamilleArticle: Semences Courgette
# Unique References (1): ['104']
#
#
# FamilleArticle: Semences Fenouil
# Unique References (1): ['116']
#
#
# FamilleArticle: Semences Persil
# Unique References (1): ['119']
#
#
# FamilleArticle: Semences Petit Pois
# Unique References (2): ['107' 'ON2738']
#
#
# FamilleArticle: Semences Pomme de tèrre
# Unique References (1): ['131']
#
#
# FamilleArticle: Semences Tomate
# Unique References (1): ['103']
#
#
# FamilleArticle: Semences carottes
# Unique References (1): ['13900-0114-71']
#
#
# FamilleArticle: Semences celeri
# Unique References (1): ['120']
#
#
# FamilleArticle: Semences coriandre
# Unique References (1): ['182']
#
#
# FamilleArticle: Semences feve
# Unique References (1): ['110']
#
#
# FamilleArticle: Semences haricot
# Unique References (1): ['115']
#
#
# FamilleArticle: Semences melon
# Unique References (1): ['102']
#
#
# FamilleArticle: Tomates_Hybride
# Unique References (2): ['202' 'B-702']
#
#
# FamilleArticle: matériels de taille
# Unique References (6): ['11000' '20000' '7311518275648' '80000' '8414299143607' '9000']
#
#
# FamilleArticle: produit biostimulant
# Unique References (2): ['125' '15000']

# %%
#fill missing values in 'Reference Produit' based on the mode (most frequent value) for each 'FamilleArticle'

# Group by 'FamilleArticle' and find the mode for each group
reference_mode = my_total_data.groupby('FamilleArticle')['Reference Produit'].apply(lambda x: x.mode().iloc[0] if not x.mode().empty else None)

# Fill missing values based on the mode of the corresponding 'FamilleArticle'
my_total_data['Reference Produit'] = my_total_data.apply(
    lambda row: reference_mode[row['FamilleArticle']] if pd.isnull(row['Reference Produit']) else row['Reference Produit'],
    axis=1
)

# Display the result
print(my_total_data[['FamilleArticle', 'Reference Produit']])
# Out:
#               FamilleArticle Reference Produit
# 0       Produit Insecticides               305
# 1             Matériel bovin               305
# 2       Produit Insecticides               305
# 3       Produit Insecticides        2F18272093
# 4       Produit Insecticides               305
# ...                      ...               ...
# 260996  Produit Insecticides               305
# 260997    Produit Fongicides               304
# 260998        Matériel bovin             11000
# 260999      Pastèque_Hybride               203
# 261000    Chou-fleur_Hybride          0111-009
#
# [261001 rows x 2 columns]

# %%
my_total_data.head()
# Out:
#    CleEffet       Date     TypeEffet        FamilleArticle Code Produit  \
# 0         1 2012-08-14  Bon d'entrée  Produit Insecticides     0305-004
# 1         1 2012-08-14  Bon d'entrée        Matériel bovin        11250
# 2         1 2012-08-14  Bon d'entrée  Produit Insecticides     0305-039
# 3         1 2012-08-14  Bon d'entrée  Produit Insecticides   2F18272093
# 4         1 2012-08-14  Bon d'entrée  Produit Insecticides     0305-054
#
#   Reference Produit         NLot Produit_Designation DetailEffet_Designation  \
# 0               305    CHA110501      Produit_Anon_0           Detail_Anon_0
# 1               305  10.274.1.09      Produit_Anon_1           Detail_Anon_1
# 2               305      L110703      Produit_Anon_2           Detail_Anon_2
# 3        2F18272093   2F18272093      Produit_Anon_3           Detail_Anon_3
# 4               305     20101102      Produit_Anon_4           Detail_Anon_4
#
#    Quantite  PrixAchat  PrixUnitaireTTC  DetailEffet_Marge   Effet_Marge  \
# 0      65.0     1650.0           9999.0                0.0  2.163109e+08
# 1     120.0      550.0           9999.0                0.0  2.163109e+08
# 2     137.0     1034.0           9999.0                0.0  2.163109e+08
# 3    2000.0     2800.0           9999.0                0.0  2.163109e+08
# 4    3500.0     1550.0           9999.0                0.0  2.163109e+08
#
#       MontantHT  Payement
# 0  2.163109e+08       0.0
# 1  2.163109e+08       0.0
# 2  2.163109e+08       0.0
# 3  2.163109e+08       0.0
# 4  2.163109e+08       0.0

# %%
missing_percentage = (my_total_data.isnull().mean() * 100).round(2)

# Display the results
print("Percentage of missing data for each column:")
print(missing_percentage)
# Out:
# Percentage of missing data for each column:
# CleEffet                    0.00
# Date                        0.00
# TypeEffet                   0.00
# FamilleArticle              0.00
# Code Produit               38.61
# Reference Produit           2.18
# NLot                       12.40
# Produit_Designation         0.00
# DetailEffet_Designation     0.00
# Quantite                    0.00
# PrixAchat                   0.00
# PrixUnitaireTTC             0.00
# DetailEffet_Marge           0.00
# Effet_Marge                 0.00
# MontantHT                   0.00
# Payement                    0.00
# dtype: float64

# %%
# Display the groups with more than one unique 'Reference Produit' after filling missing data

grouped_data = my_total_data.groupby('FamilleArticle')['Reference Produit'].nunique()

# Display the groups with more than one unique 'Reference Produit'
print("FamilleArticle with different Reference Produit:")
print(grouped_data[grouped_data > 1])
# Out:
# FamilleArticle with different Reference Produit:
# FamilleArticle
# Chou-fleur_Hybride                             3
# Courgette_Hybride                              3
# Detail                                         2
# Materiels de l'arboriculture                   9
# Matériel Avicole                               6
# Matériel Divers                               50
# Matériel Goûte à goûte                        12
# Matériel apiculture                           19
# Matériel bovin                                24
# Matériel de pompe 400 l                       17
# Matériel des moteur                            4
# Matériel jardinage                            16
# Matériel outils de préparation de la terre    12
# Matériel pulvérisation                        10
# Matériels Tronceneuses                        19
# Matériels d'irrigation                        17
# Matériels du labour                           23
# Matériels joints Spi ou Ressort                2
# Melon_Hybride                                  3
# Pastèque_Hybride                               2
# Poivron_Hybride                                2
# Produit Acaricides                             2
# Produit Engrais                               10
# Produit Fongicides                            19
# Produit Herbicides                             8
# Produit Insecticides                          26
# Prouduits Raticide + anti insect               3
# SEMENCES SEC                                   3
# Sachet potageur                                5
# Semences Mais                                  2
# Semences Navet                                 2
# Semences Persil                                2
# Semences Petit Pois                           11
# Semences Poivron                               2
# Semences Tomate                                2
# Semences carottes                              3
# Semences celeri                                2
# Semences coriandre                             2
# Semences feve                                  4
# Semences gazon                                 3
# Semences haricot                               2
# Semences laitue                                2
# Tomates_Hybride                                5
# matériels de taille                            9
# plantes olives                                 2
# produit biostimulant                           2
# Name: Reference Produit, dtype: int64

# %%
missing_percentage = (my_total_data.isnull().mean() * 100).round(2)

# Display the results
print("Percentage of missing data for each column:")
print(missing_percentage)
# Out:
# Percentage of missing data for each column:
# CleEffet                    0.00
# Date                        0.00
# TypeEffet                   0.00
# FamilleArticle              0.00
# Code Produit               38.61
# Reference Produit           2.18
# NLot                       12.40
# Produit_Designation         0.00
# DetailEffet_Designation     0.00
# Quantite                    0.00
# PrixAchat                   0.00
# PrixUnitaireTTC             0.00
# DetailEffet_Marge           0.00
# Effet_Marge                 0.00
# MontantHT                   0.00
# Payement                    0.00
# dtype: float64

# %%
# Display FamilleArticle of missing Reference Produit

missing_reference_data = my_total_data[my_total_data['Reference Produit'].isnull()]
print(missing_reference_data[['FamilleArticle']])
# Out:
#            FamilleArticle
# 2194       Laitue_Hybride
# 2195       Laitue_Hybride
# 6542    Semences Potagère
# 6550    Semences Potagère
# 6558       Laitue_Hybride
# ...                   ...
# 260471    Engrais soluble
# 260553    Engrais soluble
# 260913    Engrais soluble
# 260956  Semences Potagère
# 260968    Engrais soluble
#
# [5698 rows x 1 columns]

# %%
# Fill missing values in 'Reference Produit' with the mode for each 'FamilleArticle'
for famille_article in missing_reference_data['FamilleArticle'].unique():
    mode_reference = my_total_data.loc[my_total_data['FamilleArticle'] == famille_article, 'Reference Produit'].mode()
    if not mode_reference.empty:
        mode_reference = mode_reference.iloc[0]
        missing_reference_data.loc[missing_reference_data['FamilleArticle'] == famille_article, 'Reference Produit'] = mode_reference

# Display the updated DataFrame
print(missing_reference_data)
# Out:
#         CleEffet       Date         TypeEffet     FamilleArticle Code Produit  \
# 2194         565 2012-09-08      Bon d'entrée     Laitue_Hybride          NaN
# 2195         566 2012-09-08  Bon de livraison     Laitue_Hybride          NaN
# 6542        4017 2012-12-10  Bon de réception  Semences Potagère          NaN
# 6550        4024 2012-12-10  Bon de livraison  Semences Potagère          NaN
# 6558        4032 2012-12-10  Bon de livraison     Laitue_Hybride          NaN
# ...          ...        ...               ...                ...          ...
# 260471     68237 2022-07-17  Bon de livraison    Engrais soluble          NaN
# 260553     68257 2022-07-19  Bon de livraison    Engrais soluble          NaN
# 260913     68331 2022-07-27  Bon de livraison    Engrais soluble           43
# 260956     68338 2022-07-27  Bon de livraison  Semences Potagère          NaN
# 260968     68343 2022-07-27  Bon de livraison    Engrais soluble          NaN
#
#        Reference Produit         NLot Produit_Designation  \
# 2194                None        30269   Produit_Anon_1474
# 2195                None        30269   Produit_Anon_1474
# 6542                None       no lot   Produit_Anon_2057
# 6550                None       no lot   Produit_Anon_2057
# 6558                None        30269   Produit_Anon_1474
# ...                  ...          ...                 ...
# 260471              None      1912103   Produit_Anon_7336
# 260553              None  200107/8013   Produit_Anon_6289
# 260913              None          283   Produit_Anon_6708
# 260956              None     100115-4   Produit_Anon_5874
# 260968              None  210202/8005   Produit_Anon_6288
#
#        DetailEffet_Designation  Quantite  PrixAchat  PrixUnitaireTTC  \
# 2194          Detail_Anon_1443      17.0    1041.67              1.0
# 2195          Detail_Anon_1443       1.0    1041.67           1250.0
# 6542          Detail_Anon_2245     450.0     148.00            148.0
# 6550          Detail_Anon_2245       2.0     148.00            220.0
# 6558          Detail_Anon_2247       1.0    1041.67           1250.0
# ...                        ...       ...        ...              ...
# 260471       Detail_Anon_12379      14.0    1000.00           1050.0
# 260553        Detail_Anon_9668       4.0    6250.00          12500.0
# 260913       Detail_Anon_10588       1.0    6750.00          11250.0
# 260956        Detail_Anon_8937      15.0     110.00            125.0
# 260968        Detail_Anon_9667       2.0    6750.00          12500.0
#
#         DetailEffet_Marge  Effet_Marge  MontantHT  Payement
# 2194                 0.00        17.00       17.0       0.0
# 2195               999.00      1448.00     1450.0    1450.0
# 6542                 0.00     66600.00    66600.0       0.0
# 6550               104.00       104.00      400.0     400.0
# 6558              1199.00      1199.00     1200.0    1200.0
# ...                   ...          ...        ...       ...
# 260471            2589.00     24346.63   144215.0       0.0
# 260553           26297.68     26297.68    50000.0       0.0
# 260913            4500.00     13100.14    39750.0       0.0
# 260956             400.95      5048.76    25075.0       0.0
# 260968           12846.56     12846.56    25000.0       0.0
#
# [5698 rows x 16 columns]

# %%
missing_reference_data = my_total_data[my_total_data['Reference Produit'].isnull()]
print(missing_reference_data[['FamilleArticle']])
# Out:
#            FamilleArticle
# 2194       Laitue_Hybride
# 2195       Laitue_Hybride
# 6542    Semences Potagère
# 6550    Semences Potagère
# 6558       Laitue_Hybride
# ...                   ...
# 260471    Engrais soluble
# 260553    Engrais soluble
# 260913    Engrais soluble
# 260956  Semences Potagère
# 260968    Engrais soluble
#
# [5698 rows x 1 columns]

# %% [markdown]
# **dealing with duplicates**

# %%
# Check for duplicated rows
duplicated_rows = my_total_data[my_total_data.duplicated()]

# Display the number of duplicated rows
print("Number of duplicated rows:", len(duplicated_rows))
# Out:
# Number of duplicated rows: 651

# %%
#my_total_data = my_total_data.drop_duplicates()

# %% [markdown]
# **handling outliers**

# %%
# %matplotlib inline
my_total_data.boxplot(figsize=(20, 10))
#plt.ylim(-4, 1000000)
# Out:
# <Axes: >

# %%
my_total_data.describe()
# Out:
#             CleEffet                           Date        Quantite  \
# count  261001.000000                         261001   261001.000000
# mean    42180.635588  2017-10-25 12:07:35.998252544       34.798026
# min         1.000000            2010-03-01 00:00:00        0.000000
# 25%     31826.000000            2015-06-21 00:00:00        1.000000
# 50%     43471.000000            2017-11-26 00:00:00        2.000000
# 75%     56027.000000            2020-04-06 00:00:00        5.000000
# max     68353.000000            2022-07-28 00:00:00  1000000.000000
# std     16805.302395                            NaN     2264.039956
#
#            PrixAchat  PrixUnitaireTTC  DetailEffet_Marge   Effet_Marge  \
# count  261001.000000     2.610010e+05       2.610010e+05  2.610010e+05
# mean     2564.462161     9.224041e+05      -1.862548e+06 -1.018718e+08
# min         0.000000     0.000000e+00      -3.600000e+11 -3.599994e+11
# 25%       150.000000     2.500000e+02       6.107000e+01  3.112900e+03
# 50%       700.000000     9.000000e+02       2.914300e+02  2.228464e+04
# 75%      2750.000000     3.000000e+03       9.640800e+02  4.689462e+04
# max    392000.000000     2.400000e+11       5.839020e+06  4.800000e+11
# std      7268.100716     4.697753e+08       7.261241e+08  6.032115e+09
#
#           MontantHT      Payement
# count  2.610010e+05  2.610010e+05
# mean   2.472907e+06  1.519190e+05
# min    0.000000e+00  0.000000e+00
# 25%    2.552500e+04  0.000000e+00
# 50%    1.560340e+05  2.199904e+04
# 75%    3.302300e+05  2.498900e+05
# max    4.800000e+11  1.457000e+07
# std    9.404430e+08  2.411979e+05

# %%
#ploting only for (livraison and reception)

# %matplotlib inline


# Filter the data for 'Bon de livraison' and 'Bon de réception'
filtered_data = my_total_data[my_total_data['TypeEffet'].isin(["Bon de livraison", "Bon de réception"])]

# Create a boxplot for the 'PrixUnitaireTTC' column
filtered_data.boxplot(figsize=(20, 10))

plt.ylim(-4, 1040000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 12
#       9 # Create a boxplot for the 'PrixUnitaireTTC' column
#      10 filtered_data.boxplot(figsize=(20, 10))
# ---> 12 plt.ylim(-4, 1040000)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# **checking fiability of the attributes**

# %%
#Anything that is being sold, should have been entered before.

# Sort the DataFrame by 'Date'
my_total_data = my_total_data.sort_values(by='Date')

# Create a mask for 'Bon de livraison'
livraison_mask = my_total_data['TypeEffet'] == 'Bon de livraison'

# Iterate through the rows using iloc
for index in my_total_data[livraison_mask].index:
    row = my_total_data.iloc[index]
    item_condition = (
        (my_total_data['Reference Produit'] == row['Reference Produit']) &
        (my_total_data['FamilleArticle'] == row['FamilleArticle']) &
        (my_total_data['Code Produit'] == row['Code Produit'])
    )
    previous_entry = my_total_data.loc[item_condition & (my_total_data.index < index)]
    
    if previous_entry.empty:
        print(f"Warning: No previous entry found for item {row['Reference Produit']} - {row['FamilleArticle']} before 'Bon de livraison' at index {index}")

# %%
#Check if Effet_Marge is the sum of DetailEffet_Marge for one transaction.

# %%
#check if montant of a product in bon dentrée is the same in de livraison + calculate the difference


# Create a mask for 'Bon de livraison'
livraison_mask = my_total_data['TypeEffet'] == 'Bon de livraison'

# Iterate through the rows using iloc
for index in my_total_data[livraison_mask].index:
    row = my_total_data.iloc[index]
    item_condition = (
        (my_total_data['Reference Produit'] == row['Reference Produit']) &
        (my_total_data['FamilleArticle'] == row['FamilleArticle']) &
        (my_total_data['Code Produit'] == row['Code Produit'])
    )
    
    # Check for previous entry with 'TypeEffet' equal to 'Bon d'entrée'
    previous_entree = my_total_data.loc[item_condition & (my_total_data['TypeEffet'] == "Bon d'entrée") & (my_total_data.index < index)]
    
    if not previous_entree.empty:
        # Calculate the difference in MontantHT
        diff_amount = row['MontantHT'] - previous_entree.iloc[-1]['MontantHT']
        print(f"Product {row['Reference Produit']} - {row['FamilleArticle']} at index {index}: Difference in MontantHT = {diff_amount}")

# %%
#how many


# Sort the DataFrame by 'Date'
my_total_data = my_total_data.sort_values(by='Date')

# Create variables to count changes
same_count = 0
changed_count = 0

# Create a mask for 'Bon de livraison'
livraison_mask = my_total_data['TypeEffet'] == 'Bon de livraison'

# Iterate through the rows using iloc
for index in my_total_data[livraison_mask].index:
    row = my_total_data.iloc[index]
    item_condition = (
        (my_total_data['Reference Produit'] == row['Reference Produit']) &
        (my_total_data['FamilleArticle'] == row['FamilleArticle']) &
        (my_total_data['Code Produit'] == row['Code Produit'])
        
    )
    
    # Check for previous entry with 'TypeEffet' equal to 'Bon d'entrée'
    previous_entree = my_total_data.loc[item_condition & (my_total_data['TypeEffet'] == "Bon d'entrée") & (my_total_data.index < index)]
    
    if not previous_entree.empty:
        # Calculate the difference in MontantHT
        diff_amount = row['MontantHT'] - previous_entree.iloc[-1]['MontantHT']
        
        if diff_amount == 0:
            same_count += 1
        else:
            changed_count += 1

# Print the results
print(f"Number of entries where MontantHT stayed the same: {same_count}")
print(f"Number of entries where MontantHT changed: {changed_count}")

# %%
#check if same product have been sold again with different mantant and how much the difference 

# Create a dictionary to store the differences
differences = {}

# Create a mask for 'Bon de livraison'
livraison_mask = my_total_data['TypeEffet'] == 'Bon de livraison'

# Iterate through the rows using iloc
for index in my_total_data[livraison_mask].index:
    row = my_total_data.iloc[index]
    
    # Check if the product has been sold again with different MontantHT
    same_product_condition = (
        (my_total_data['Reference Produit'] == row['Reference Produit']) &
        (my_total_data['FamilleArticle'] == row['FamilleArticle']) &
        (my_total_data['Code Produit'] == row['Code Produit'])
    )
    
    # Check for previous entry with 'TypeEffet' equal to 'Bon de livraison'
    previous_livraison = my_total_data.loc[same_product_condition & (my_total_data['TypeEffet'] == 'Bon de livraison') & (my_total_data.index < index)]
    
    if not previous_livraison.empty:
        # Calculate the difference in MontantHT
        diff_amount = row['MontantHT'] - previous_livraison.iloc[-1]['MontantHT']
        
        # Store the difference in the dictionary
        differences[index] = diff_amount

# Print the results
for index, diff in differences.items():
    print(f"Product {my_total_data.loc[index, 'Reference Produit']} at index {index}: MontantHT changed by {diff}")

# %%
# the best sales depending on the season ( avec mantants de bon de livraison)

import pandas as pd
import matplotlib.pyplot as plt


# Define a function to determine the season based on the month
def get_season(month):
    if 3 <= month <= 5:
        return 'Spring'
    elif 6 <= month <= 8:
        return 'Summer'
    elif 9 <= month <= 11:
        return 'Fall'
    else:
        return 'Winter'

# Create a new column 'Season' based on the 'Date' column
my_total_data['Season'] = my_total_data['Date'].dt.month.apply(get_season)

# Filter for 'Bon de livraison'
livraison_data = my_total_data[my_total_data['TypeEffet'] == 'Bon de livraison']

# Group by 'Season' and calculate the sum of MontantHT
seasonal_sales = livraison_data.groupby('Season')['MontantHT'].sum()

# Plot the results
seasonal_sales.plot(kind='bar', color='skyblue')
plt.title('Seasonal Sales Comparison')
plt.xlabel('Season')
plt.ylabel('Total Sales (MontantHT)')
plt.show()

# %%
# what famille article was sold more in spring

import pandas as pd
import matplotlib.pyplot as plt

# Assuming you already have the 'Season' column in your DataFrame

# Filter for 'Bon de livraison' and 'Spring' season
spring_livraison_data = my_total_data[(my_total_data['TypeEffet'] == 'Bon de livraison') & (my_total_data['Season'] == 'Spring')]

# Group by 'FamilleArticle' and calculate the sum of MontantHT
spring_sales_by_famille = spring_livraison_data.groupby('FamilleArticle')['MontantHT'].sum()

# Plot the results
spring_sales_by_famille.sort_values(ascending=False).plot(kind='bar', color='green')
plt.title('Spring Sales by FamilleArticle')
plt.xlabel('FamilleArticle')
plt.ylabel('Total Sales (MontantHT)')
plt.show()

# %%
my_total_data.head()
# Out:
#    CleEffet       Date     TypeEffet        FamilleArticle Code Produit  \
# 0         1 2012-08-14  Bon d'entrée  Produit Insecticides     0305-004
# 1         1 2012-08-14  Bon d'entrée        Matériel bovin        11250
# 2         1 2012-08-14  Bon d'entrée  Produit Insecticides     0305-039
# 3         1 2012-08-14  Bon d'entrée  Produit Insecticides   2F18272093
# 4         1 2012-08-14  Bon d'entrée  Produit Insecticides     0305-054
#
#   Reference Produit         NLot Produit_Designation DetailEffet_Designation  \
# 0               305    CHA110501      Produit_Anon_0           Detail_Anon_0
# 1               305  10.274.1.09      Produit_Anon_1           Detail_Anon_1
# 2               305      L110703      Produit_Anon_2           Detail_Anon_2
# 3        2F18272093   2F18272093      Produit_Anon_3           Detail_Anon_3
# 4               305     20101102      Produit_Anon_4           Detail_Anon_4
#
#    Quantite  PrixAchat  PrixUnitaireTTC  DetailEffet_Marge   Effet_Marge  \
# 0      65.0     1650.0           9999.0                0.0  2.163109e+08
# 1     120.0      550.0           9999.0                0.0  2.163109e+08
# 2     137.0     1034.0           9999.0                0.0  2.163109e+08
# 3    2000.0     2800.0           9999.0                0.0  2.163109e+08
# 4    3500.0     1550.0           9999.0                0.0  2.163109e+08
#
#       MontantHT  Payement  Season
# 0  2.163109e+08       0.0  Summer
# 1  2.163109e+08       0.0  Summer
# 2  2.163109e+08       0.0  Summer
# 3  2.163109e+08       0.0  Summer
# 4  2.163109e+08       0.0  Summer

# %%
#how many : check if montant of a product in bon dentrée is the same in de livraison + calculate the difference 
import pandas as pd

def calculate_montant_changes(data):
    # Sort the DataFrame by 'Date'
    data = data.sort_values(by='Date')

    # Create variables to count changes
    same_count = 0
    changed_count = 0

    # Create a mask for 'Bon de livraison'
    livraison_mask = data['TypeEffet'] == 'Bon de livraison'

    # Iterate through the rows using iterrows
    for index, row in data[livraison_mask].iterrows():
        item_condition = (
            (data['Reference Produit'] == row['Reference Produit']) &
            (data['FamilleArticle'] == row['FamilleArticle']) &
            (data['Code Produit'] == row['Code Produit'])
        )

        # Check for previous entry with 'TypeEffet' equal to 'Bon d'entrée'
        previous_entree = data.loc[item_condition & (data['TypeEffet'] == "Bon d'entrée") & (data.index < index)]

        if not previous_entree.empty:
            # Calculate the difference in MontantHT
            diff_amount = row['MontantHT'] - previous_entree.iloc[-1]['MontantHT']

            if diff_amount == 0:
                same_count += 1
            else:
                changed_count += 1

    return same_count, changed_count

# Call the function with your DataFrame
same_count, changed_count = calculate_montant_changes(my_total_data)

# Print the results
print(f"Number of entries where MontantHT stayed the same: {same_count}")
print(f"Number of entries where MontantHT changed: {changed_count}")

# %%
# what famille article was sold more in winter 

import pandas as pd
import matplotlib.pyplot as plt

# Assuming you already have the 'Season' column in your DataFrame

# Filter for 'Bon de livraison' and 'Spring' season
spring_livraison_data = my_total_data[(my_total_data['TypeEffet'] == 'Bon de livraison') & (my_total_data['Season'] == 'winter')]

# Group by 'FamilleArticle' and calculate the sum of MontantHT
spring_sales_by_famille = spring_livraison_data.groupby('FamilleArticle')['MontantHT'].sum()

# Plot the results
spring_sales_by_famille.sort_values(ascending=False).plot(kind='bar', color='green')
plt.title('winter Sales by FamilleArticle')
plt.xlabel('FamilleArticle')
plt.ylabel('Total Sales (MontantHT)')
plt.show()
